# %%
import pandas as pd

# %%
df = pd.read_csv("merkel.csv",index_col=0)

# %%
df.head()
# Out:
#               Tweet_id                                               Text  \
# 0  1240680304999895042  Seien Sie kein Vollpfosten, bleiben Sie zu Hau...
# 1  1240575348867293185  Wer die #Merkelrede zur #Coronakrise für eine ...
# 2  1247466215276240896  Merkels Pressekonferenz: Vage beim Gesundheits...
# 3  1247174743175974912  Das #ZDF schneidet einfach den #Live Auftritt ...
# 4  1246815726293450752  Die Mäuse wählen immer die Schlange, die sie a...
#
#                User_id date_published  \
# 0  1094625306642657280     03/19/2020
# 1             58285254     03/19/2020
# 2            101470141     04/07/2020
# 3   962767496871858176     04/06/2020
# 4            296470411     04/05/2020
#
#                                            tweet url      keyword language
# 0  https://twitter.com/browserballett/status/1240...  #Merkelrede       DE
# 1  https://twitter.com/DrKissler/status/124057534...  #Merkelrede       DE
# ...

# %%
df
# Out:
#                  Tweet_id                                               Text  \
# 0     1240680304999895042  Seien Sie kein Vollpfosten, bleiben Sie zu Hau...
# 1     1240575348867293185  Wer die #Merkelrede zur #Coronakrise für eine ...
# 2     1247466215276240896  Merkels Pressekonferenz: Vage beim Gesundheits...
# 3     1247174743175974912  Das #ZDF schneidet einfach den #Live Auftritt ...
# 4     1246815726293450752  Die Mäuse wählen immer die Schlange, die sie a...
# ...                   ...                                                ...
# 1336  1240401441786933248  Abstand ist der neue Anstand. \n\n#Coron #COVI...
# 1337  1240599449858199552  #Ansprache (Deutsche Twitter Trends am 19.03.2...
# 1338  1240339267253161985  #Merkel : "Diese Situation ist ernst, und sie ...
# 1339  1240526061693063169  Looking for graphic design, Background Remove,...
# 1340  1240401537517719552  @le_fuchs ~ The girl does it right, clearly, d...
#
#                   User_id date_published  \
# ...

# %%
#for english (same for german)
df[df["language"]== "EN"]
# Out:
#                  Tweet_id                                               Text  \
# 42    1241976714571497474  #Merkelrede #AngelaMerkel deservedly getting g...
# 43    1241790288315715587  #Merkelrede  light \n#coronavirus #wirbleibenz...
# 44    1240426010648154114  So froh in diesem Land zu leben #Merkelrede #C...
# 45    1241646425181691906  In order to trust the government, one must fir...
# 46    1241610397637120001  The Leader of the Free World Gives a Speech, a...
# ...                   ...                                                ...
# 1336  1240401441786933248  Abstand ist der neue Anstand. \n\n#Coron #COVI...
# 1337  1240599449858199552  #Ansprache (Deutsche Twitter Trends am 19.03.2...
# 1338  1240339267253161985  #Merkel : "Diese Situation ist ernst, und sie ...
# 1339  1240526061693063169  Looking for graphic design, Background Remove,...
# 1340  1240401537517719552  @le_fuchs ~ The girl does it right, clearly, d...
#
#                   User_id date_published  \
# ...
