# %%
import pandas as pd

# %%
df = pd.read_csv("merkel121.csv",index_col=0)

# %%
df.head()
# Out:
#               Tweet_id                                               Text  ...  keyword language
# 0  1250686813917908992  Muss echt bitter sein für die AfD. Angela Merk...  ...   Merkel       DE
# 1  1250730699000291328  Um jede Infektionskette nachverfolgen zu könne...  ...   Merkel       DE
# 2  1251071580635086849  ShutDown: Merkel, RKI, Drosten und Gates nennt...  ...   Merkel       DE
# 3  1251244288161255431  So, nun muss ich mich auch mal zum Thema #Schu...  ...   Merkel       DE
# 4  1250755150945423360  - Angela Merkel setzt in der Corona-Krise auf ...  ...   Merkel       DE
#
# [5 rows x 7 columns]

# %%
df
# Out:
#                  Tweet_id                                               Text  ...  keyword language
# 0     1250686813917908992  Muss echt bitter sein für die AfD. Angela Merk...  ...   Merkel       DE
# 1     1250730699000291328  Um jede Infektionskette nachverfolgen zu könne...  ...   Merkel       DE
# 2     1251071580635086849  ShutDown: Merkel, RKI, Drosten und Gates nennt...  ...   Merkel       DE
# 3     1251244288161255431  So, nun muss ich mich auch mal zum Thema #Schu...  ...   Merkel       DE
# 4     1250755150945423360  - Angela Merkel setzt in der Corona-Krise auf ...  ...   Merkel       DE
# ...                   ...                                                ...  ...      ...      ...
# 4959  1248894535880630272  Frau Merkel hat das ganze Parteiengefüge nach ...  ...   Merkel       EN
# 4960  1248882283706277888  Wann werden Eisdielen endlich als systemreleva...  ...   Merkel       EN
# ...

# %%
#for english (same for german)
df[df["language"]== "EN"]
# Out:
#                  Tweet_id                                               Text  ...  keyword language
# 2564  1236700451036450816  In der Union wächst die Furcht vor den Wählern...  ...   Merkel       EN
# 2565  1236736114599346178  Auf allen Kanälen unsere Kanzlerin Angela Merk...  ...   Merkel       EN
# 2566  1236656169994858499  Merkel lädt zur Facebook-Party ein, um »cool« ...  ...   Merkel       EN
# 2567  1236701415806025728  Nachdem unser Drehhofer Grenzkontrollen und Hä...  ...   Merkel       EN
# 2568  1236691440098476042  Bundestags-Vize Hans-Peter Friedrich kritisier...  ...   Merkel       EN
# ...                   ...                                                ...  ...      ...      ...
# 4959  1248894535880630272  Frau Merkel hat das ganze Parteiengefüge nach ...  ...   Merkel       EN
# 4960  1248882283706277888  Wann werden Eisdielen endlich als systemreleva...  ...   Merkel       EN
# ...
